# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# plt.style.use('science')

# %%
data = pd.read_csv("graph/comparison.csv")

# %%
data
# Out:
#      Epoch  Barlow Twins  Autoencoder
# 0        0        0.5260       0.4258
# 1        1        0.5860       0.4734
# 2        2        0.6122       0.4944
# 3        3        0.6322       0.5154
# 4        4        0.6442       0.5334
# ..     ...           ...          ...
# 145    145        0.7218       0.6778
# 146    146        0.7216       0.6780
# 147    147        0.7218       0.6780
# 148    148        0.7218       0.6782
# 149    149        0.7222       0.6782
#
# [150 rows x 3 columns]

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b:blue、g:green、r:red、c:cyan、m:magenta、y:yellow、k:black、w:white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['Epoch'], data['Barlow Twins'], color="b",
         label="Barlow Twins", linewidth=1.5)
plt.plot(data['Epoch'], data['Autoencoder'], color="r",
         label="Autoencoder", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
# plt.xlim(0.9, 6.1)
plt.ylim(0, 1)

# plt.legend() 
plt.legend(loc=0, numpoints=1)
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=16)

# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/comparison.svg', format='svg')
plt.show()

# %%
data = pd.read_csv("graph/lr.csv")

# %%
data
# Out:
#      epoch        lr      loss
# 0      0.0  0.000001  2.527014
# 1      1.0  0.000001  2.226297
# 2      2.0  0.000001  2.106523
# 3      3.0  0.000001  1.960253
# 4      4.0  0.000002  1.998005
# ..     ...       ...       ...
# 97    97.0  0.008310  3.370988
# 98    98.0  0.009112  3.366191
# 99    99.0  0.009991  3.397932
# 100    NaN       NaN       NaN
# 101    NaN       NaN       NaN
#
# [102 rows x 3 columns]

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b:blue、g:green、r:red、c:cyan、m:magenta、y:yellow、k:black、w:white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['epoch'], data['lr'], color="b", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Learning Rate", fontsize=20)

plt.savefig('graph/lr1.svg', format='svg')
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b: blue、g: green、r: red、c: cyan、m: magenta、y: yellow、k: black、w: white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['lr'], data['loss'], color="r", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Learning Rate", fontsize=20)
plt.ylabel("Training Loss", fontsize=20)

ax.set_xscale('log')
# plt.xlim(0.9, 6.1)
# plt.ylim(1.5, 16)


# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/lr2.svg', format='svg')
plt.show()

# %%
data = pd.read_csv("graph/lambda.csv")

# %%
data
# Out:
#    lambda     acc
# 0       0  0.6072
# 1       1  0.6380
# 2       5  0.6574
# 3      10  0.6594
# 4      20  0.6782
# 5      50  0.6694
# 6     100  0.6556
# 7     200  0.6514
# 8     500  0.6136

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b: blue、g: green、r: red、c: cyan、m: magenta、y: yellow、k: black、w: white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['lambda'], data['acc'], color="r", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("$\lambda$", fontsize=20)
plt.ylabel("Validation Accuracy", fontsize=20)

ax.set_xscale('symlog')
plt.xlim(0, 500)
# plt.ylim(1.5, 16)


# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/lambda.svg', format='svg')
plt.show()

# %%
data = pd.read_csv("graph/decoder.csv")

# %%
data
# Out:
#    lambda    acc1    acc2    acc3    acc4
# 0       1  0.6190  0.6380  0.6554  0.6266
# 1       5  0.6344  0.6574  0.6516  0.6650
# 2      10  0.6554  0.6594  0.6534  0.6714
# 3      20  0.6654  0.6782  0.6618  0.6690
# 4      50  0.6676  0.6694  0.6598  0.6708
# 5     100  0.6698  0.6556  0.6478  0.6590

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b:blue、g:green、r:red、c:cyan、m:magenta、y:yellow、k:black、w:white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['lambda'], data['acc1'], color="b",
         label="FC dim = 3072", linewidth=1.5)
plt.plot(data['lambda'], data['acc2'], color="r",
         label="FC dim = 8192", linewidth=1.5)
plt.plot(data['lambda'], data['acc3'], color="g",
         label="FC dim = 16384", linewidth=1.5)
plt.plot(data['lambda'], data['acc4'], color="c",
         label="2 ConvTranspose2d layers", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("$\lambda$", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
# plt.xlim(0.9, 6.1)
# plt.ylim(1.5, 16)

# plt.legend()
plt.legend(loc=0, numpoints=1)
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=16)

ax.set_xscale('log')

# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/decoder.svg', format='svg')
plt.show()

# %%
data = pd.read_csv("graph/decoder2.csv")

# %%
data
# Out:
#      epoch   loss 16  val loss 16    loss 3  val loss 3    loss 8  val loss 8
# 0        0  2.107288     1.939948  1.988512    1.754003  2.014178    1.815130
# 1        1  1.843106     1.766992  1.666017    1.588913  1.727070    1.654016
# 2        2  1.708606     1.667318  1.538503    1.495408  1.602682    1.562405
# 3        3  1.623113     1.598995  1.456737    1.430931  1.522782    1.497887
# 4        4  1.560964     1.547289  1.396884    1.382585  1.463489    1.448251
# ..     ...       ...          ...       ...         ...       ...         ...
# 145    145  0.819353     1.012885  0.677676    1.004991  0.746163    0.980157
# 146    146  0.817935     1.012488  0.676206    1.005082  0.744747    0.979928
# 147    147  0.816527     1.012109  0.674740    1.005186  0.743339    0.979711
# 148    148  0.815127     1.011730  0.673283    1.005275  0.741944    0.979484
# 149    149  0.813734     1.011358  0.671843    1.005368  0.740554    0.979267
#
# [150 rows x 7 columns]

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b:blue、g:green、r:red、c:cyan、m:magenta、y:yellow、k:black、w:white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['epoch'], data['loss 3'], color="b",
         label="FC dim = 3072", linewidth=1.5)
plt.plot(data['epoch'], data['loss 8'], color="r",
         label="FC dim = 8192", linewidth=1.5)
plt.plot(data['epoch'], data['loss 16'], color="g",
         label="FC dim = 16384", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Loss", fontsize=20)
# plt.xlim(0.9, 6.1)
# plt.ylim(1.5, 16)

# plt.legend()
plt.legend(loc=0, numpoints=1)
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=16)

# ax.set_xscale('log')

# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/decoder2.svg', format='svg')
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# color：b:blue、g:green、r:red、c:cyan、m:magenta、y:yellow、k:black、w:white、、、
# 线型：-  --   -.  :    ,
# marker：.  ,   o   v    <    *    +    1
plt.figure(figsize=(8, 6), dpi=400)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
ax = plt.gca()
ax.spines['top'].set_visible(False)  # 去掉上边框
ax.spines['right'].set_visible(False)  # 去掉右边框

plt.plot(data['epoch'], data['val loss 3'], color="b",
         label="FC dim = 3072", linewidth=1.5)
plt.plot(data['epoch'], data['val loss 8'], color="r",
         label="FC dim = 8192", linewidth=1.5)
plt.plot(data['epoch'], data['val loss 16'], color="g",
         label="FC dim = 16384", linewidth=1.5)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Epoch", fontsize=20)
plt.ylabel("Loss", fontsize=20)
# plt.xlim(0.9, 6.1)
# plt.ylim(1.5, 16)

# plt.legend()
plt.legend(loc=0, numpoints=1)
leg = plt.gca().get_legend()
ltext = leg.get_texts()
plt.setp(ltext, fontsize=16)

# ax.set_xscale('log')

# 建议保存为svg格式,再用inkscape转为矢量图emf后插入word中
plt.savefig('graph/decoder3.svg', format='svg')
plt.show()
